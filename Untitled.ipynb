# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,Y = make_regression(n_samples=4,n_features=1,n_informative=1,n_targets=1,noise=80,random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,Y)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X,Y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# 26.15963284313262

# %%
# We have to find the intercept by using the gradient decent

# %%
plt.scatter(X,Y)
plt.plot(X,reg.predict(X),color='red')

# %%
# Assume the slope of the graient decent to be the 78.35
# Let be start the maping with the b =0
y_pred = ((78.35 * X)+0).reshape(4)

# %%
plt.scatter(X,Y)
plt.plot(X,reg.predict(X),color='red',label='Ols')
plt.plot(X,y_pred,color='blue',label='b=0')
plt.legend()
plt.show()

# %%
# For the next to apply the GD we have to calculat the b new(for this we have to calculate the slope of that point)
# For the slpe we have to calculate the dl by db

# %%
m = 78.35
b = 0
loss_slope = -2 * np.sum(Y-m* X.ravel()-b)
loss_slope
# Out:
# -209.27763408209216

# %%
# Take the learning rate 0.1
lr = 0.1
step_size = loss_slope * lr
step_size
# Out:
# -20.927763408209216

# %%
b1 =  b - step_size
b1
# Out:
# 20.927763408209216

# %%
y_pred1 = ((78.35 * X) + b1).reshape(4)

plt.scatter(X,Y)
plt.plot(X,reg.predict(X),color='red',label='Ols')
plt.plot(X,y_pred,color='blue',label='b=0')
plt.plot(X,y_pred1,color='black',label='b=20.2')
plt.legend()
plt.show()

# %%
# Itration 2
m = 78.35
b1 = 20.927763408209216
loss_slope = -2 * np.sum(Y-m* X.ravel()-b1)
loss_slope
# Out:
# -41.85552681641843

# %%
lr = 0.1
step_size = loss_slope * lr
step_size
# Out:
# -4.185552681641844

# %%
b2 =  b1 - step_size
b2
# Out:
# 25.11331608985106

# %%
y_pred2 = ((78.35 * X) + b2).reshape(4)
plt.scatter(X,Y)
plt.plot(X,reg.predict(X),color='red',label='Ols')
# plt.plot(X,y_pred,color='blue',label='b=0')
# plt.plot(X,y_pred1,color='black',label='b=20.2')
plt.plot(X,y_pred1,color='blue',label='-41.85')
plt.legend()
plt.show()

# %%
# Itration 3
m = 78.35
b2 = 25.11
loss_slope = -2 * np.sum(Y-m* X.ravel()-b2)
loss_slope
# Out:
# -8.397634082092168

# %%
lr = 0.1
step_size = loss_slope * lr
step_size
# Out:
# -0.8397634082092168

# %%
b3 =  b2 - step_size
b3
# Out:
# 25.949763408209215

# %%
y_pred3 = ((78.35 * X) + b3).reshape(4)
plt.scatter(X,Y)
plt.plot(X,reg.predict(X),color='red',label='Ols')
# plt.plot(X,y_pred,color='blue',label='b=0')
# plt.plot(X,y_pred1,color='black',label='b=20.2')
# plt.plot(X,y_pred1,color='blue',label='-41.85')
plt.plot(X,y_pred1,color='blue',label='25.94')
plt.legend()
plt.show()

# %%
# All the step in the one loop

b= -100 # it is the intercept of the graph (it changs with the graph)
m = 78.35
lr = 0.01

epoches = 10000 # noo f time we draw the graph 
for i in range(epoches):
    loss_slope = -2 * np.sum(Y- m * X.ravel() - b)
    b= b - (lr * loss_slope)
    y_pred = m * X + b
    plt.plot(X,y_pred)
plt.scatter(X,Y)

# %% [markdown]
# Now We wiil create the class of the
# 1. For calculatin the b
# 2. For calculating the slope of the graph

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
import numpy as np

# %%
X,Y = make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20)

# %%
plt.scatter(X,Y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,Y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [38.65035101]
# 0.8624580086053357

# %%
m = 38.65

# %%
class GDregressor:
    
    def __init__ (self,epoches,learning_rate):
            self.lr = learning_rate
            self.epoches = epoches
            self.b = -120
            self.m = 38.65
    def fit(self,X,Y):
        # caculatig the b 
        for i in range (self.epoches):
            loss_slope = -2 * np.sum(Y-self.m* X.ravel()-self.b)
            self.b= self.b - (self.lr * loss_slope)
            print(loss_slope,self.b)
        print(self.b)

# %%
GD = GDregressor(1000,0.001)

# %%
GD.fit(X,Y)
# Out:
# -23414.635194260707 -96.58536480573929
# -18731.70815540856 -77.85365665033072
# -14985.36652432685 -62.86829012600387
# -11988.29321946148 -50.87999690654239
# -9590.634575569184 -41.289362330973205
# -7672.507660455345 -33.61685467051786
# -6138.006128364277 -27.47884854215358
# -4910.404902691422 -22.56844363946216
# -3928.3239221531376 -18.640119717309023
# -3142.659137722511 -15.497460579586512
# -2514.1273101780075 -12.983333269408504
# -2011.3018481424065 -10.972031421266099
# -1609.0414785139255 -9.362989942752174
# -1287.2331828111408 -8.075756759941033
# -1029.7865462489124 -7.0459702136921205
# -823.82923699913 -6.222140976692991
# -659.063389599304 -5.563077587093687
# -527.2507116794434 -5.035826875414244
# -421.8005693435547 -4.61402630607069
# -337.44045547484376 -4.276585850595846
# -269.95236437987506 -4.006633486215971
# -215.9618915039001 -3.7906715947120713
# -172.76951320312008 -3.617902081508951
# -138.21561056249618 -3.479686470946455
# ...

# %% [markdown]
# Now We are create the programm where both the m and b are chenginh

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import cross_val_score

# %%
X,Y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)
plt.scatter(X,Y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=2)

from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X_train,Y_train)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [28.12597332]
# -2.271014426178382

# %%
Y_pred = lr.predict(X_test)
from sklearn.metrics import r2_score
r2_score(Y_test,Y_pred)
# Out:
# 0.6345158782661013

# %%
class GDRegressor_with_m_and_b_:
    
    def __init__(self,learning_rate,epochs):
        self.m = 100
        self.b = -120
        self.lr = learning_rate
        self.epochs = epochs
        
    def fit(self,X,y):
        # calcualte the b an m using GD
        for i in range(self.epochs):
            loss_slope_b = -2 * np.sum(y - self.m*X.ravel() - self.b)
            loss_slope_m = -2 * np.sum((y - self.m*X.ravel() - self.b)*X.ravel())
            
            self.b = self.b - (self.lr * loss_slope_b)
            self.m = self.m - (self.lr * loss_slope_m)
        print(self.m,self.b)
        
    def predict(self,X):
        return self.m * X + self.b

# %%
gd = GDRegressor_with_m_and_b_(0.01,100)

# %%
gd.fit(X_train,Y_train)
# Out:
# 28.12597331513561 -2.271014426178381

# %%
Y_pred = gd.predict(X_test)
from sklearn.metrics import r2_score
r2_score(Y_test,Y_pred)
# Out:
# 0.6345158782661013
